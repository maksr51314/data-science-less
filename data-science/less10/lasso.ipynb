# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet

boston = load_boston()

data = boston.data
target = boston.target

la = Lasso()
ri = Ridge()

# la.path()
alphas = np.logspace(-5, 2, 1000)

alphas, coefs, _ = la.path(data, target, alphas=alphas)

# coefs[:10]

plt.plot(alphas, coefs.T)
# Out:
# [<matplotlib.lines.Line2D at 0x10878e940>,
#  <matplotlib.lines.Line2D at 0x10878eb00>,
#  <matplotlib.lines.Line2D at 0x10878ec50>,
#  <matplotlib.lines.Line2D at 0x10878eda0>,
#  <matplotlib.lines.Line2D at 0x10878eef0>,
#  <matplotlib.lines.Line2D at 0x108786080>,
#  <matplotlib.lines.Line2D at 0x1087861d0>,
#  <matplotlib.lines.Line2D at 0x108786320>,
#  <matplotlib.lines.Line2D at 0x108786470>,
#  <matplotlib.lines.Line2D at 0x1087865c0>,
#  <matplotlib.lines.Line2D at 0x10873e5f8>,
#  <matplotlib.lines.Line2D at 0x108786828>,
#  <matplotlib.lines.Line2D at 0x108786978>]

# %%
f, ax = plt.subplots()
plt.plot(alphas, coefs.T)
ax.set_xscale("log")

# %%
from sklearn.linear_model import ElasticNetCV

en = ElasticNetCV(l1_ratio=[.1,.5,.7,.9,.95,.99])
en.fit(data, target)
en.alpha_
# Out:
# 1.4496408567545191

# %%
en.score(data, target)
# Out:
# 0.6712666394054048
